# %% [markdown]
# Support python 3.6
# The implementaion script is in object_detection_yolo/clssifiierimg.py
# Library necessary for this object detection
# open-cv   (pip install opencv-python)
# numpy     (pip install numpy)
# time      (pip install numpy)
# operator  (pip install operator)
# matplotlib(pip install matplotlib)

# %%
import cv2
from darkflow.net.build import TFNet
import numpy as np
import time
import operator
import matplotlib.pyplot as plt

# %%
options = {
    "model":"cfg/yolo-voc.2.0.cfg",
    "load":"bin/YOLOv2_logo_detection_10000th_iteration.weights",
    "thrsehold":0.8
}

# %%
tfnet=TFNet(options)
img=cv2.imread('smirnoff_testing/hp26.jpg')
img1=cv2.imread('smirnoff_testing/hp26.jpg',cv2.IMREAD_COLOR)
# Out:
# C:\Users\SACHIN\Machine_Learning\object_detection_yolo\darkflow\dark\darknet.py:54: UserWarning: ./cfg/YOLOv2_logo_detection_10000th_iteration.cfg not found, use cfg/yolo-voc.2.0.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolo-voc.2.0.cfg
# Loading bin/YOLOv2_logo_detection_10000th_iteration.weights ...
# Successfully identified 269185952 bytes
# Finished in 0.04712557792663574s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
# ...

# %%
result=tfnet.return_predict(img)
print(result)
tl=(result[0]['topleft']['x'],result[0]['topleft']['y'])
br=(result[0]['bottomright']['x'],result[0]['bottomright']['y'])
label=result[0]['label']
# Out:
# [{'bottomright': {'x': 359, 'y': 170}, 'confidence': 0.0, 'label': 'HP', 'topleft': {'x': 269, 'y': 77}}, {'bottomright': {'x': 358, 'y': 168}, 'confidence': 0.8722787, 'label': 'HP', 'topleft': {'x': 278, 'y': 77}}]

# %%
img=cv2.rectangle(img,tl,br,(0,255,0),7)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
tfnet=TFNet(options)
img=cv2.imread('smirnoff_testing/apple3.jpg')
img1=cv2.imread('smirnoff_testing/apple3.jpg',cv2.IMREAD_COLOR)
# Out:
# C:\Users\SACHIN\Machine_Learning\object_detection_yolo\darkflow\dark\darknet.py:54: UserWarning: ./cfg/YOLOv2_logo_detection_10000th_iteration.cfg not found, use cfg/yolo-voc.2.0.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolo-voc.2.0.cfg
# Loading bin/YOLOv2_logo_detection_10000th_iteration.weights ...
# Successfully identified 269185952 bytes
# Finished in 0.028073549270629883s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
# ...

# %%
result=tfnet.return_predict(img)
print(result)
tl=(result[0]['topleft']['x'],result[0]['topleft']['y'])
br=(result[0]['bottomright']['x'],result[0]['bottomright']['y'])
label=result[0]['label']
# Out:
# [{'bottomright': {'x': 488, 'y': 277}, 'confidence': 0.8635657, 'label': 'apple', 'topleft': {'x': 419, 'y': 196}}]

# %%
img=cv2.rectangle(img,tl,br,(0,255,0),7)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
#coke15.jpg
tfnet=TFNet(options)
img=cv2.imread('smirnoff_testing/coke15.jpg')
img1=cv2.imread('smirnoff_testing/coke15.jpg',cv2.IMREAD_COLOR)
# Out:
# C:\Users\SACHIN\Machine_Learning\object_detection_yolo\darkflow\dark\darknet.py:54: UserWarning: ./cfg/YOLOv2_logo_detection_10000th_iteration.cfg not found, use cfg/yolo-voc.2.0.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolo-voc.2.0.cfg
# Loading bin/YOLOv2_logo_detection_10000th_iteration.weights ...
# Successfully identified 269185952 bytes
# Finished in 0.033086538314819336s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
# ...

# %%
result=tfnet.return_predict(img)
print(result)
tl=(result[0]['topleft']['x'],result[0]['topleft']['y'])
br=(result[0]['bottomright']['x'],result[0]['bottomright']['y'])
label=result[0]['label']
# Out:
# [{'bottomright': {'x': 1563, 'y': 1130}, 'confidence': 0.87977475, 'label': 'cocacola', 'topleft': {'x': 826, 'y': 763}}]

# %%
img=cv2.rectangle(img,tl,br,(0,255,0),7)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
